# %%
import pandas as pd
import matplotlib.pyplot as plt
Weather={
    "date":["2026-06-15","2026-06-16","2026-06-17","2026-06-18","2026-06-19","2026-06-21","2026-06-22"],
    "weather":["Sunny","Clear","Partly_Sunny","Cloudy","Rainy","Rainy","Rainy"],
    "high_temp":[33,32,33,33,34,34,34],
    "low_temp":[21,22,22,23,24,23,23]
}
df=pd.DataFrame(Weather)
df.to_csv("weatherData.csv",index=False)
rainy_days=df[df["high_temp"]>33]
print(rainy_days)
rainy=df[df["weather"]=="Rainy"]
print(rainy)
plt.figure(figsize=(8,5))
plt.plot(df["date"],df["high_temp"])
plt.title("high_temperature")
plt.xlabel("date")
plt.ylabel("temperature")
plt.grid()
plt.show()
import pandas as pd
from sklearn.linear_model import LinearRegression
df= pd.DataFrame({
    "day":[1,2,3,4,5,6,7],
    "temp":[33,32,33,33,34,34,34]
})
X= df[["day"]]
Y= df[["temp"]]
model=LinearRegression()
model.fit(X,Y)
prediction=model.predict(pd.DataFrame([[8]],columns=['day']))
print(prediction)
# Out:
#          date weather  high_temp  low_temp
# 4  2026-06-19   Rainy         34        24
# 5  2026-06-21   Rainy         34        23
# 6  2026-06-22   Rainy         34        23
#          date weather  high_temp  low_temp
# 4  2026-06-19   Rainy         34        24
# 5  2026-06-21   Rainy         34        23
# 6  2026-06-22   Rainy         34        23
# [[34.42857143]]
